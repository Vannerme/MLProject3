# %%
#Load packages
import urllib2, sys
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import sys
reload(sys)
sys.setdefaultencoding('utf8')

# %%
# Identify the URL of the Website to scrape
site = "http://www.loc.gov/standards/iso639-2/php/code_list.php"

hdr = {'User-Agent': 'Mozilla/5.0'}
req = urllib2.Request(site,headers=hdr)
page = urllib2.urlopen(req)
soup = BeautifulSoup(page)

# %%
#Let's grab the column headers from the table. 
#In this case, the headers start in row 1 (hence limit 1)
column_headers = [th.getText() for th in 
                  soup.findAll('tr', limit=1)[0].findAll('th')]
print column_headers

# %%
#Now let's get the data to fill in the table. 
#The data is table format so a 2 dimensional list is needed. 
#Use 2: to skip the first row (headers)
data_rows = soup.findAll('tr')[2:]

# %%
# now we have a list of table rows
print type(data_rows)

# %%
#Now we combine the column_header list with the data_row list
lang_cd = [[td.getText() for td in data_rows[i].findAll(['td','th'])] for i in range(len(data_rows))]

# %%
# Create an empty list to hold all the data
langcd_ls = []

# %%
# Now pass the list to the empty list
for i in range(len(data_rows)):  # for each table row
    code_row = []  # create an empty list for each pick/player

    # for each table data element from each table row
    for td in data_rows[i].findAll('td'):        
        # get the text content and append to the player_row 
        code_row.append(td.getText())        

    # then append each pick/player to the player_data matrix
    langcd_ls.append(code_row)

print lang_cd == langcd_ls

# %%
#Now we can create the data frame named df for the data extracted from the Website

lang_df = pd.DataFrame(lang_cd, columns=column_headers)

# %%
lang_df.head()
# Out:
#   ISO 639-2 Code ISO 639-1 Code English name of Language  \
# 0            aar             aa                     Afar
# 1            abk             ab                Abkhazian
# 2            ace                                Achinese
# 3            ach                                   Acoli
# 4            ada                                 Adangme
#
#   French name of Language German name of Language
# 0                    afar         Danakil-Sprache
# 1                 abkhaze              Abchasisch
# 2                    aceh            Aceh-Sprache
# 3                   acoli          Acholi-Sprache
# 4                 adangme         Adangme-Sprache

# %%
lang_df
# Out:
#                        ISO 639-2 Code                    ISO 639-1 Code  \
# 0                                 aar                                aa
# 1                                 abk                                ab
# 2                                 ace
# 3                                 ach
# 4                                 ada
# 5                                 ady
# 6                                 afa
# 7                                 afh
# 8                                 afr                                af
# 9                                 ain
# 10                                aka                                ak
# 11                                akk
# 12                     alb (B)sqi (T)                                sq
# 13                                ale
# 14                                alg
# 15                                alt
# 16                                amh                                am
# 17                                ang
# 18                                anp
# 19                                apa
# 20                                ara                                ar
# 21                                arc
# 22                                arg                                an
# 23                     arm (B)hye (T)                                hy
# 24                                arn
# 25                                arp
# 26                                art
# 27                                arw
# 28                                asm                                as
# 29                                ast
# ..                                ...                               ...
# 478                               vie                                vi
# 479                               vol                                vo
# 480                               vot
# 481                               wak
# 482                               wal
# 483                               war
# 484                               was
# 485                    wel (B)cym (T)                                cy
# 486                               wen
# 487                               wln                                wa
# 488                               wol                                wo
# 489                               xal
# 490                               xho                                xh
# 491                               yao
# 492                               yap
# 493                               yid                                yi
# 494                               yor                                yo
# 495                               ypk
# 496                               zap
# 497                               zbl
# 498                               zen
# 499                               zgh
# 500                               zha                                za
# 501                    chi (B)zho (T)                                zh
# 502                               znd
# 503                               zul                                zu
# 504                               zun
# 505                               zxx
# 506                               zza
# 507  Library of Congress >> Standards  Legal | External Link Disclaimer
#
#                               English name of Language  \
# 0                                                 Afar
# 1                                            Abkhazian
# 2                                             Achinese
# 3                                                Acoli
# 4                                              Adangme
# 5                                       Adyghe; Adygei
# 6                               Afro-Asiatic languages
# 7                                             Afrihili
# 8                                            Afrikaans
# 9                                                 Ainu
# 10                                                Akan
# 11                                            Akkadian
# 12                                            Albanian
# 13                                               Aleut
# 14                                Algonquian languages
# 15                                      Southern Altai
# 16                                             Amharic
# 17                          English, Old (ca.450-1100)
# 18                                              Angika
# 19                                    Apache languages
# 20                                              Arabic
# 21   Official Aramaic (700-300 BCE); Imperial Arama...
# 22                                           Aragonese
# 23                                            Armenian
# 24                                 Mapudungun; Mapuche
# 25                                             Arapaho
# 26                                Artificial languages
# 27                                              Arawak
# 28                                            Assamese
# 29              Asturian; Bable; Leonese; Asturleonese
# ..                                                 ...
# 478                                         Vietnamese
# 479                                            Volapük
# 480                                              Votic
# 481                                 Wakashan languages
# 482                                 Wolaitta; Wolaytta
# 483                                              Waray
# 484                                              Washo
# 485                                              Welsh
# 486                                  Sorbian languages
# 487                                            Walloon
# 488                                              Wolof
# 489                                      Kalmyk; Oirat
# 490                                              Xhosa
# 491                                                Yao
# 492                                             Yapese
# 493                                            Yiddish
# 494                                             Yoruba
# 495                                    Yupik languages
# 496                                            Zapotec
# 497                  Blissymbols; Blissymbolics; Bliss
# 498                                             Zenaga
# 499                        Standard Moroccan Tamazight
# 500                                     Zhuang; Chuang
# 501                                            Chinese
# 502                                    Zande languages
# 503                                               Zulu
# 504                                               Zuni
# 505              No linguistic content; Not applicable
# 506     Zaza; Dimili; Dimli; Kirdki; Kirmanjki; Zazaki
# 507        Contact \r\n            Us\nJuly 25, 2013\n
#
#                             French name of Language  \
# 0                                              afar
# 1                                           abkhaze
# 2                                              aceh
# 3                                             acoli
# 4                                           adangme
# 5                                            adyghé
# 6                          afro-asiatiques, langues
# 7                                          afrihili
# 8                                         afrikaans
# 9                                             aïnou
# 10                                             akan
# 11                                         akkadien
# 12                                         albanais
# 13                                          aléoute
# 14                             algonquines, langues
# 15                                     altai du Sud
# 16                                        amharique
# 17                        anglo-saxon (ca.450-1100)
# 18                                           angika
# 19                                 apaches, langues
# 20                                            arabe
# 21                   araméen d'empire (700-300 BCE)
# 22                                        aragonais
# 23                                         arménien
# 24                      mapudungun; mapuche; mapuce
# 25                                          arapaho
# 26                           artificielles, langues
# 27                                           arawak
# 28                                         assamais
# 29          asturien; bable; léonais; asturoléonais
# ..                                              ...
# 478                                      vietnamien
# 479                                         volapük
# 480                                            vote
# 481                             wakashanes, langues
# 482                              wolaitta; wolaytta
# 483                                           waray
# 484                                           washo
# 485                                         gallois
# 486                                sorabes, langues
# 487                                          wallon
# 488                                           wolof
# 489                                  kalmouk; oïrat
# 490                                           xhosa
# 491                                             yao
# 492                                          yapois
# 493                                         yiddish
# 494                                          yoruba
# 495                                  yupik, langues
# 496                                       zapotèque
# 497                           symboles Bliss; Bliss
# 498                                          zenaga
# 499                      amazighe standard marocain
# 500                                  zhuang; chuang
# 501                                         chinois
# 502                                  zandé, langues
# 503                                          zoulou
# 504                                            zuni
# 505     pas de contenu linguistique; non applicable
# 506  zaza; dimili; dimli; kirdki; kirmanjki; zazaki
# 507                                            None
#
#                 German name of Language
# 0                       Danakil-Sprache
# 1                            Abchasisch
# 2                          Aceh-Sprache
# 3                        Acholi-Sprache
# 4                       Adangme-Sprache
# 5                              Adygisch
# 6    Hamitosemitische Sprachen (Andere)
# 7                              Afrihili
# 8                             Afrikaans
# 9                          Ainu-Sprache
# 10                         Akan-Sprache
# 11                            Akkadisch
# 12                            Albanisch
# 13                            Aleutisch
# 14           Algonkin-Sprachen (Andere)
# 15                             Altaisch
# 16                            Amharisch
# 17                          Altenglisch
# 18                         Anga-Sprache
# 19                     Apachen-Sprachen
# 20                             Arabisch
# 21                            Aramäisch
# 22                         Aragonesisch
# 23                            Armenisch
# 24                      Arauka-Sprachen
# 25                      Arapaho-Sprache
# 26               Kunstsprachen (Andere)
# 27                      Arawak-Sprachen
# 28                          Assamesisch
# 29                            Asturisch
# ..                                  ...
# 478                       Vietnamesisch
# 479                             Volapük
# 480                             Wotisch
# 481                     Wakash-Sprachen
# 482                      Walamo-Sprache
# 483                               Waray
# 484                       Washo-Sprache
# 485                            Kymrisch
# 486                   Sorbisch (Andere)
# 487                          Wallonisch
# 488                       Wolof-Sprache
# 489                         Kalmückisch
# 490                       Xhosa-Sprache
# 491          Yao-Sprache (Bantusprache)
# 492                           Yapesisch
# 493                            Jiddisch
# 494                      Yoruba-Sprache
# 495                       Ypik-Sprachen
# 496                         Zapotekisch
# 497                        Bliss-Symbol
# 498                              Zenaga
# 499
# 500                              Zhuang
# 501                          Chinesisch
# 502                      Zande-Sprachen
# 503                        Zulu-Sprache
# 504                        Zuñi-Sprache
# 505          Kein linguistischer Inhalt
# 506                              Zazaki
# 507                                None
#
# [508 rows x 5 columns]

# %%
lst_col = 'ISO 639-2 Code' 
x = lang_df.assign(**{lst_col:lang_df[lst_col].str.split(')')})
x
# Out:
#                          ISO 639-2 Code                    ISO 639-1 Code  \
# 0                                 [aar]                                aa
# 1                                 [abk]                                ab
# 2                                 [ace]
# 3                                 [ach]
# 4                                 [ada]
# 5                                 [ady]
# 6                                 [afa]
# 7                                 [afh]
# 8                                 [afr]                                af
# 9                                 [ain]
# 10                                [aka]                                ak
# 11                                [akk]
# 12                   [alb (B, sqi (T, ]                                sq
# 13                                [ale]
# 14                                [alg]
# 15                                [alt]
# 16                                [amh]                                am
# 17                                [ang]
# 18                                [anp]
# 19                                [apa]
# 20                                [ara]                                ar
# 21                                [arc]
# 22                                [arg]                                an
# 23                   [arm (B, hye (T, ]                                hy
# 24                                [arn]
# 25                                [arp]
# 26                                [art]
# 27                                [arw]
# 28                                [asm]                                as
# 29                                [ast]
# ..                                  ...                               ...
# 478                               [vie]                                vi
# 479                               [vol]                                vo
# 480                               [vot]
# 481                               [wak]
# 482                               [wal]
# 483                               [war]
# 484                               [was]
# 485                  [wel (B, cym (T, ]                                cy
# 486                               [wen]
# 487                               [wln]                                wa
# 488                               [wol]                                wo
# 489                               [xal]
# 490                               [xho]                                xh
# 491                               [yao]
# 492                               [yap]
# 493                               [yid]                                yi
# 494                               [yor]                                yo
# 495                               [ypk]
# 496                               [zap]
# 497                               [zbl]
# 498                               [zen]
# 499                               [zgh]
# 500                               [zha]                                za
# 501                  [chi (B, zho (T, ]                                zh
# 502                               [znd]
# 503                               [zul]                                zu
# 504                               [zun]
# 505                               [zxx]
# 506                               [zza]
# 507  [Library of Congress >> Standards]  Legal | External Link Disclaimer
#
#                               English name of Language  \
# 0                                                 Afar
# 1                                            Abkhazian
# 2                                             Achinese
# 3                                                Acoli
# 4                                              Adangme
# 5                                       Adyghe; Adygei
# 6                               Afro-Asiatic languages
# 7                                             Afrihili
# 8                                            Afrikaans
# 9                                                 Ainu
# 10                                                Akan
# 11                                            Akkadian
# 12                                            Albanian
# 13                                               Aleut
# 14                                Algonquian languages
# 15                                      Southern Altai
# 16                                             Amharic
# 17                          English, Old (ca.450-1100)
# 18                                              Angika
# 19                                    Apache languages
# 20                                              Arabic
# 21   Official Aramaic (700-300 BCE); Imperial Arama...
# 22                                           Aragonese
# 23                                            Armenian
# 24                                 Mapudungun; Mapuche
# 25                                             Arapaho
# 26                                Artificial languages
# 27                                              Arawak
# 28                                            Assamese
# 29              Asturian; Bable; Leonese; Asturleonese
# ..                                                 ...
# 478                                         Vietnamese
# 479                                            Volapük
# 480                                              Votic
# 481                                 Wakashan languages
# 482                                 Wolaitta; Wolaytta
# 483                                              Waray
# 484                                              Washo
# 485                                              Welsh
# 486                                  Sorbian languages
# 487                                            Walloon
# 488                                              Wolof
# 489                                      Kalmyk; Oirat
# 490                                              Xhosa
# 491                                                Yao
# 492                                             Yapese
# 493                                            Yiddish
# 494                                             Yoruba
# 495                                    Yupik languages
# 496                                            Zapotec
# 497                  Blissymbols; Blissymbolics; Bliss
# 498                                             Zenaga
# 499                        Standard Moroccan Tamazight
# 500                                     Zhuang; Chuang
# 501                                            Chinese
# 502                                    Zande languages
# 503                                               Zulu
# 504                                               Zuni
# 505              No linguistic content; Not applicable
# 506     Zaza; Dimili; Dimli; Kirdki; Kirmanjki; Zazaki
# 507        Contact \r\n            Us\nJuly 25, 2013\n
#
#                             French name of Language  \
# 0                                              afar
# 1                                           abkhaze
# 2                                              aceh
# 3                                             acoli
# 4                                           adangme
# 5                                            adyghé
# 6                          afro-asiatiques, langues
# 7                                          afrihili
# 8                                         afrikaans
# 9                                             aïnou
# 10                                             akan
# 11                                         akkadien
# 12                                         albanais
# 13                                          aléoute
# 14                             algonquines, langues
# 15                                     altai du Sud
# 16                                        amharique
# 17                        anglo-saxon (ca.450-1100)
# 18                                           angika
# 19                                 apaches, langues
# 20                                            arabe
# 21                   araméen d'empire (700-300 BCE)
# 22                                        aragonais
# 23                                         arménien
# 24                      mapudungun; mapuche; mapuce
# 25                                          arapaho
# 26                           artificielles, langues
# 27                                           arawak
# 28                                         assamais
# 29          asturien; bable; léonais; asturoléonais
# ..                                              ...
# 478                                      vietnamien
# 479                                         volapük
# 480                                            vote
# 481                             wakashanes, langues
# 482                              wolaitta; wolaytta
# 483                                           waray
# 484                                           washo
# 485                                         gallois
# 486                                sorabes, langues
# 487                                          wallon
# 488                                           wolof
# 489                                  kalmouk; oïrat
# 490                                           xhosa
# 491                                             yao
# 492                                          yapois
# 493                                         yiddish
# 494                                          yoruba
# 495                                  yupik, langues
# 496                                       zapotèque
# 497                           symboles Bliss; Bliss
# 498                                          zenaga
# 499                      amazighe standard marocain
# 500                                  zhuang; chuang
# 501                                         chinois
# 502                                  zandé, langues
# 503                                          zoulou
# 504                                            zuni
# 505     pas de contenu linguistique; non applicable
# 506  zaza; dimili; dimli; kirdki; kirmanjki; zazaki
# 507                                            None
#
#                 German name of Language
# 0                       Danakil-Sprache
# 1                            Abchasisch
# 2                          Aceh-Sprache
# 3                        Acholi-Sprache
# 4                       Adangme-Sprache
# 5                              Adygisch
# 6    Hamitosemitische Sprachen (Andere)
# 7                              Afrihili
# 8                             Afrikaans
# 9                          Ainu-Sprache
# 10                         Akan-Sprache
# 11                            Akkadisch
# 12                            Albanisch
# 13                            Aleutisch
# 14           Algonkin-Sprachen (Andere)
# 15                             Altaisch
# 16                            Amharisch
# 17                          Altenglisch
# 18                         Anga-Sprache
# 19                     Apachen-Sprachen
# 20                             Arabisch
# 21                            Aramäisch
# 22                         Aragonesisch
# 23                            Armenisch
# 24                      Arauka-Sprachen
# 25                      Arapaho-Sprache
# 26               Kunstsprachen (Andere)
# 27                      Arawak-Sprachen
# 28                          Assamesisch
# 29                            Asturisch
# ..                                  ...
# 478                       Vietnamesisch
# 479                             Volapük
# 480                             Wotisch
# 481                     Wakash-Sprachen
# 482                      Walamo-Sprache
# 483                               Waray
# 484                       Washo-Sprache
# 485                            Kymrisch
# 486                   Sorbisch (Andere)
# 487                          Wallonisch
# 488                       Wolof-Sprache
# 489                         Kalmückisch
# 490                       Xhosa-Sprache
# 491          Yao-Sprache (Bantusprache)
# 492                           Yapesisch
# 493                            Jiddisch
# 494                      Yoruba-Sprache
# 495                       Ypik-Sprachen
# 496                         Zapotekisch
# 497                        Bliss-Symbol
# 498                              Zenaga
# 499
# 500                              Zhuang
# 501                          Chinesisch
# 502                      Zande-Sprachen
# 503                        Zulu-Sprache
# 504                        Zuñi-Sprache
# 505          Kein linguistischer Inhalt
# 506                              Zazaki
# 507                                None
#
# [508 rows x 5 columns]

# %%
lang_codemod=pd.DataFrame({
     ...:     col:np.repeat(x[col].values, x[lst_col].str.len())
     ...:     for col in x.columns.difference([lst_col])
     ...: }).assign(**{lst_col:np.concatenate(x[lst_col].values)})[x.columns.tolist()]
     ...:

# %%
lang_codemod_nomissing = lang_codemod[~lang_codemod['ISO 639-2 Code'].isin([''])]

# %%
lang_codemod_nomissing = lang_codemod_nomissing.rename(columns={'ISO 639-2 Code': 'ISO6392Code'})

# %%
n=3

# %%
lang_codemod_nomissing.ISO6392Code[:-n]
# Out:
# 0         aar
# 1         abk
# 2         ace
# 3         ach
# 4         ada
# 5         ady
# 6         afa
# 7         afh
# 8         afr
# 9         ain
# 10        aka
# 11        akk
# 12     alb (B
# 13     sqi (T
# 15        ale
# 16        alg
# 17        alt
# 18        amh
# 19        ang
# 20        anp
# 21        apa
# 22        ara
# 23        arc
# 24        arg
# 25     arm (B
# 26     hye (T
# 28        arn
# 29        arp
# 30        art
# 31        arw
#         ...
# 553       ven
# 554       vie
# 555       vol
# 556       vot
# 557       wak
# 558       wal
# 559       war
# 560       was
# 561    wel (B
# 562    cym (T
# 564       wen
# 565       wln
# 566       wol
# 567       xal
# 568       xho
# 569       yao
# 570       yap
# 571       yid
# 572       yor
# 573       ypk
# 574       zap
# 575       zbl
# 576       zen
# 577       zgh
# 578       zha
# 579    chi (B
# 580    zho (T
# 582       znd
# 583       zul
# 584       zun
# Name: ISO6392Code, Length: 545, dtype: object

# %%
lang_codemod_nomissing
# Out:
#                           ISO6392Code                    ISO 639-1 Code  \
# 0                                 aar                                aa
# 1                                 abk                                ab
# 2                                 ace
# 3                                 ach
# 4                                 ada
# 5                                 ady
# 6                                 afa
# 7                                 afh
# 8                                 afr                                af
# 9                                 ain
# 10                                aka                                ak
# 11                                akk
# 12                             alb (B                                sq
# 13                             sqi (T                                sq
# 15                                ale
# 16                                alg
# 17                                alt
# 18                                amh                                am
# 19                                ang
# 20                                anp
# 21                                apa
# 22                                ara                                ar
# 23                                arc
# 24                                arg                                an
# 25                             arm (B                                hy
# 26                             hye (T                                hy
# 28                                arn
# 29                                arp
# 30                                art
# 31                                arw
# ..                                ...                               ...
# 556                               vot
# 557                               wak
# 558                               wal
# 559                               war
# 560                               was
# 561                            wel (B                                cy
# 562                            cym (T                                cy
# 564                               wen
# 565                               wln                                wa
# 566                               wol                                wo
# 567                               xal
# 568                               xho                                xh
# 569                               yao
# 570                               yap
# 571                               yid                                yi
# 572                               yor                                yo
# 573                               ypk
# 574                               zap
# 575                               zbl
# 576                               zen
# 577                               zgh
# 578                               zha                                za
# 579                            chi (B                                zh
# 580                            zho (T                                zh
# 582                               znd
# 583                               zul                                zu
# 584                               zun
# 585                               zxx
# 586                               zza
# 587  Library of Congress >> Standards  Legal | External Link Disclaimer
#
#                               English name of Language  \
# 0                                                 Afar
# 1                                            Abkhazian
# 2                                             Achinese
# 3                                                Acoli
# 4                                              Adangme
# 5                                       Adyghe; Adygei
# 6                               Afro-Asiatic languages
# 7                                             Afrihili
# 8                                            Afrikaans
# 9                                                 Ainu
# 10                                                Akan
# 11                                            Akkadian
# 12                                            Albanian
# 13                                            Albanian
# 15                                               Aleut
# 16                                Algonquian languages
# 17                                      Southern Altai
# 18                                             Amharic
# 19                          English, Old (ca.450-1100)
# 20                                              Angika
# 21                                    Apache languages
# 22                                              Arabic
# 23   Official Aramaic (700-300 BCE); Imperial Arama...
# 24                                           Aragonese
# 25                                            Armenian
# 26                                            Armenian
# 28                                 Mapudungun; Mapuche
# 29                                             Arapaho
# 30                                Artificial languages
# 31                                              Arawak
# ..                                                 ...
# 556                                              Votic
# 557                                 Wakashan languages
# 558                                 Wolaitta; Wolaytta
# 559                                              Waray
# 560                                              Washo
# 561                                              Welsh
# 562                                              Welsh
# 564                                  Sorbian languages
# 565                                            Walloon
# 566                                              Wolof
# 567                                      Kalmyk; Oirat
# 568                                              Xhosa
# 569                                                Yao
# 570                                             Yapese
# 571                                            Yiddish
# 572                                             Yoruba
# 573                                    Yupik languages
# 574                                            Zapotec
# 575                  Blissymbols; Blissymbolics; Bliss
# 576                                             Zenaga
# 577                        Standard Moroccan Tamazight
# 578                                     Zhuang; Chuang
# 579                                            Chinese
# 580                                            Chinese
# 582                                    Zande languages
# 583                                               Zulu
# 584                                               Zuni
# 585              No linguistic content; Not applicable
# 586     Zaza; Dimili; Dimli; Kirdki; Kirmanjki; Zazaki
# 587        Contact \r\n            Us\nJuly 25, 2013\n
#
#                             French name of Language  \
# 0                                              afar
# 1                                           abkhaze
# 2                                              aceh
# 3                                             acoli
# 4                                           adangme
# 5                                            adyghé
# 6                          afro-asiatiques, langues
# 7                                          afrihili
# 8                                         afrikaans
# 9                                             aïnou
# 10                                             akan
# 11                                         akkadien
# 12                                         albanais
# 13                                         albanais
# 15                                          aléoute
# 16                             algonquines, langues
# 17                                     altai du Sud
# 18                                        amharique
# 19                        anglo-saxon (ca.450-1100)
# 20                                           angika
# 21                                 apaches, langues
# 22                                            arabe
# 23                   araméen d'empire (700-300 BCE)
# 24                                        aragonais
# 25                                         arménien
# 26                                         arménien
# 28                      mapudungun; mapuche; mapuce
# 29                                          arapaho
# 30                           artificielles, langues
# 31                                           arawak
# ..                                              ...
# 556                                            vote
# 557                             wakashanes, langues
# 558                              wolaitta; wolaytta
# 559                                           waray
# 560                                           washo
# 561                                         gallois
# 562                                         gallois
# 564                                sorabes, langues
# 565                                          wallon
# 566                                           wolof
# 567                                  kalmouk; oïrat
# 568                                           xhosa
# 569                                             yao
# 570                                          yapois
# 571                                         yiddish
# 572                                          yoruba
# 573                                  yupik, langues
# 574                                       zapotèque
# 575                           symboles Bliss; Bliss
# 576                                          zenaga
# 577                      amazighe standard marocain
# 578                                  zhuang; chuang
# 579                                         chinois
# 580                                         chinois
# 582                                  zandé, langues
# 583                                          zoulou
# 584                                            zuni
# 585     pas de contenu linguistique; non applicable
# 586  zaza; dimili; dimli; kirdki; kirmanjki; zazaki
# 587                                            None
#
#                 German name of Language
# 0                       Danakil-Sprache
# 1                            Abchasisch
# 2                          Aceh-Sprache
# 3                        Acholi-Sprache
# 4                       Adangme-Sprache
# 5                              Adygisch
# 6    Hamitosemitische Sprachen (Andere)
# 7                              Afrihili
# 8                             Afrikaans
# 9                          Ainu-Sprache
# 10                         Akan-Sprache
# 11                            Akkadisch
# 12                            Albanisch
# 13                            Albanisch
# 15                            Aleutisch
# 16           Algonkin-Sprachen (Andere)
# 17                             Altaisch
# 18                            Amharisch
# 19                          Altenglisch
# 20                         Anga-Sprache
# 21                     Apachen-Sprachen
# 22                             Arabisch
# 23                            Aramäisch
# 24                         Aragonesisch
# 25                            Armenisch
# 26                            Armenisch
# 28                      Arauka-Sprachen
# 29                      Arapaho-Sprache
# 30               Kunstsprachen (Andere)
# 31                      Arawak-Sprachen
# ..                                  ...
# 556                             Wotisch
# 557                     Wakash-Sprachen
# 558                      Walamo-Sprache
# 559                               Waray
# 560                       Washo-Sprache
# 561                            Kymrisch
# 562                            Kymrisch
# 564                   Sorbisch (Andere)
# 565                          Wallonisch
# 566                       Wolof-Sprache
# 567                         Kalmückisch
# 568                       Xhosa-Sprache
# 569          Yao-Sprache (Bantusprache)
# 570                           Yapesisch
# 571                            Jiddisch
# 572                      Yoruba-Sprache
# 573                       Ypik-Sprachen
# 574                         Zapotekisch
# 575                        Bliss-Symbol
# 576                              Zenaga
# 577
# 578                              Zhuang
# 579                          Chinesisch
# 580                          Chinesisch
# 582                      Zande-Sprachen
# 583                        Zulu-Sprache
# 584                        Zuñi-Sprache
# 585          Kein linguistischer Inhalt
# 586                              Zazaki
# 587                                None
#
# [548 rows x 5 columns]

# %%
# Finally, save the dataframe as a CSV
#lang_df.to_csv('/home/jon/MLproject3/data/LangCodes.csv', index=False)
